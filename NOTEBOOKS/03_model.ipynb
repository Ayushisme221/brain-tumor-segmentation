# %%
import sys
sys.path.append("..")

# %%
import torch
from src.model import UNet3D
model = UNet3D(in_channels=4, num_classes=4)
dummy_input = torch.randn(1, 4, 128, 128, 128)  # small test volume, not full 240x240x155 — that'd be slow/memory-heavy for a quick test
output = model(dummy_input)
print(output.shape)  # expect (1, 4, 128, 128, 128)
# Out:
# torch.Size([1, 4, 128, 128, 128])
