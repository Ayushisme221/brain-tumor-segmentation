# %%
import sys
sys.path.append("..")

# %%
import src.dataloader as dl
print(dl.__file__)
print(dir(dl))
# Out:
# e:\brain tumor segmentation and analysis using cnn\NOTEBOOKS\..\src\dataloader.py
# ['BraTSDataset', 'Dataset', '__builtins__', '__cached__', '__doc__', '__file__', '__loader__', '__name__', '__package__', '__spec__', 'nib', 'np', 'os']

# %%
from src.dataloader import BraTSDataset

dataset = BraTSDataset(r"E:\brain tumor segmentation and analysis using cnn\datasets\BraTS2020_TrainingData\MICCAI_BraTS2020_TrainingData")
print(len(dataset))
image, label = dataset[0]
print(image.shape, label.shape)
# Out:
# 369
# (4, 240, 240, 155) (240, 240, 155)

# %%
import torch
print(torch.cuda.is_available())
print(torch.cuda.get_device_name(0) if torch.cuda.is_available() else "No GPU detected — will run on CPU")
# Out:
# False
# No GPU detected — will run on CPU
